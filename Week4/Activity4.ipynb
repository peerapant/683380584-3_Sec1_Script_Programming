# %% [markdown]
# ## Activity 4.1
#
#
# 1. อุณหภูมิรายวันในรอบสัปดาห์ ใช้ List เนื่องจาก อุณหภูมิเป็นข้อมูลที่มีลำดับ (วันจันทร์-อาทิตย์) และอาจมีการอัปเดต แก้ไข หรือบันทึกเติมเข้ามาเรื่อยๆ (Mutable)
# 2. ค่าสี RGB ของเฉดสีเฉพาะ ใช้ Tuple เนื่องจาก ค่าสี RGB ของสีใดสีหนึ่งมีแม่แบบตายตัว 3 ค่า (R, G, B) ลำดับมีความหมายชัดเจน และไม่ควรถูกแก้ไขเปลี่ยนแปลง (Immutable)
# 3. สินค้าในรถเข็นช้อปปิ้ง ใช้ List เนื่องจาก รายการสินค้าเปลี่ยนตลอดเวลา สามารถเพิ่มสินค้า (append) หรือหยิบออก (remove) ได้ตลอดการช้อปปิ้ง (Mutable)
# 4. วันในหนึ่งสัปดาห์ตามลำดับ ใช้ Tuple เนื่องจาก จำนวนวันและลำดับจันทร์-อาทิตย์เป็นค่าคงที่ในทางธรรมชาติ ไม่มีการเพิ่ม ลบ หรือสลับตำแหน่ง (Immutable)
# 5. คะแนนสอบของนักเรียน ใช้ List เนื่องจาก คะแนนสามารถกรอกเพิ่มเมื่อมีการส่งงานใหม่ หรือตรวจซ้ำแล้วแก้ไขปรับปรุงคะแนนได้ (Mutable)
# 6. พิกัด GPS ของสถานที่สำคัญ ใช้ Tuple เนื่องจาก ละติจูดและลองจิจูดของสถานที่คงที่มีตำแหน่งตายตัว ลำดับค่าสำคัญมาก และไม่ควรถูกเปลี่ยนแปลงโดยไม่ตั้งใจ (Immutable)

# %% [markdown]
# ## Activity 4.2

# %%
todo_list = []

while true:
    print("1. Add a task")
    print("2. View tasks")
    print("3. Mark task as complete (remove by index or name)")
    print("4. Exit")

    menu = input("Enter menu :")

    if menu == 1:
        add = input("Enter task :")
        todo_list.append(add)

    if menu == 2:
        print(f"All task : {todo_list}")
    
    if menu == 3:
        task_done = input("Enter name or index of completed task :")
        if int(task_done):
            todo_list.remove()
